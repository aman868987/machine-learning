# %% [markdown]
# <a href="https://colab.research.google.com/github/aman868987/machine-learning/blob/master/linearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# In this , i m trying to learn linear regression by playing with dataset of usa_house information.the dataset is enclosed with this file.
# i m trying to do the analysis and predict the price of houses depending upon the various features.

# %%
df=pd.read_csv('/content/USA_Housing.csv') #reading data and creating dataframe

# %%
df.head(n=10) #printing data with 10 rows
# Out:
#    Avg. Area Income  ...                                            Address
# 0      79545.458574  ...  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1      79248.642455  ...  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2      61287.067179  ...  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3      63345.240046  ...                          USS Barnett\nFPO AP 44820
# 4      59982.197226  ...                         USNS Raymond\nFPO AE 09386
# 5      80175.754159  ...  06039 Jennifer Islands Apt. 443\nTracyport, KS...
# 6      64698.463428  ...  4759 Daniel Shoals Suite 442\nNguyenburgh, CO ...
# 7      78394.339278  ...     972 Joyce Viaduct\nLake William, TN 17778-6483
# 8      59927.660813  ...                          USS Gilbert\nFPO AA 20957
# 9      81885.927184  ...                   Unit 9446 Box 0958\nDPO AE 97025
#
# [10 rows x 7 columns]

# %%
df.info() #gives the info of data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
# Avg. Area Income                5000 non-null float64
# Avg. Area House Age             5000 non-null float64
# Avg. Area Number of Rooms       5000 non-null float64
# Avg. Area Number of Bedrooms    5000 non-null float64
# Area Population                 5000 non-null float64
# Price                           5000 non-null float64
# Address                         5000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  ...  Area Population         Price
# count       5000.000000          5000.000000  ...      5000.000000  5.000000e+03
# mean       68583.108984             5.977222  ...     36163.516039  1.232073e+06
# std        10657.991214             0.991456  ...      9925.650114  3.531176e+05
# min        17796.631190             2.644304  ...       172.610686  1.593866e+04
# 25%        61480.562388             5.322283  ...     29403.928702  9.975771e+05
# 50%        68804.286404             5.970429  ...     36199.406689  1.232669e+06
# 75%        75783.338666             6.650808  ...     42861.290769  1.471210e+06
# max       107701.748378             9.519088  ...     69621.713378  2.469066e+06
#
# [8 rows x 6 columns]

# %%
sns.pairplot(df) #plots histograms and sctarred for each column

# %%
sns.distplot(df['Price'])

# %%
df.corr()
# Out:
#                               Avg. Area Income  ...     Price
# Avg. Area Income                      1.000000  ...  0.639734
# Avg. Area House Age                  -0.002007  ...  0.452543
# Avg. Area Number of Rooms            -0.011032  ...  0.335664
# Avg. Area Number of Bedrooms          0.019788  ...  0.171071
# Area Population                      -0.016234  ...  0.408556
# Price                                 0.639734  ...  1.000000
#
# [6 rows x 6 columns]

# %%
sns.heatmap(df.corr(),annot=True)

# %%
#training
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
x=df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
y=df['Price'] #target data

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.4,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(lm.intercept_)
# Out:
# -2640159.796853739

# %%
lm.coef_
# Out:
# array([2.15282755e+01, 1.64883282e+05, 1.22368678e+05, 2.23380186e+03,
#        1.51504200e+01])

# %%
xtrain.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population'],
#       dtype='object')

# %%
cdf=pd.DataFrame(lm.coef_,x.columns,columns=['Coeff'])

# %%
cdf
# Out:
#                                       Coeff
# Avg. Area Income                  21.528276
# Avg. Area House Age           164883.282027
# Avg. Area Number of Rooms     122368.678027
# Avg. Area Number of Bedrooms    2233.801864
# Area Population                   15.150420

# %%
#prediction
prdctn=lm.predict(xtest)

# %%
prdctn #predicted prices
# Out:
# array([1260960.70567629,  827588.75560301, 1742421.24254363, ...,
#         372191.40626868, 1365217.15140901, 1914519.54178955])

# %%
ytest #actual prices
# Out:
# 1718    1.251689e+06
# 2511    8.730483e+05
# 345     1.696978e+06
# 2521    1.063964e+06
# 54      9.487883e+05
#             ...
# 1776    1.489520e+06
# 4269    7.777336e+05
# 1661    1.515271e+05
# 2410    1.343824e+06
# 2302    1.906025e+06
# Name: Price, Length: 2000, dtype: float64

# %%
plt.scatter(ytest,prdctn)

# %%
sns.distplot((ytest-prdctn))

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(ytest,prdctn)
# Out:
# 82288.22251914928

# %%
metrics.mean_squared_error(ytest,prdctn)
# Out:
# 10460958907.208244
